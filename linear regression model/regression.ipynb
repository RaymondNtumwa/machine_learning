# %% [markdown]
# ## Training a linear Regression Model

# %%
import pandas as pd

# %%
# %pip install xlrd

# %%
data = pd.read_excel(r"Concrete_Data.xls")
data.head()

# %%
data.dtypes

# %%
data.shape

# %%
data.combine

# %%
data.columns

# %%
from sklearn.model_selection import train_test_split
### target and the predictors

ml_data = data.copy()
x = ml_data.drop(columns=['Concrete compressive strength(MPa, megapascals) '])
y = ml_data['Concrete compressive strength(MPa, megapascals) ']

### training set and  testing set 

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)

print(f"training X: {x_train.shape} Y: {y_train.shape}")
print(f"Testing X: {x_test.shape} Y: {y_test.shape}")

# %%
# Tell the model (lr) to predict the values for the test set
y_predictions = lr.predict(x_test)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

lr.fit(x_train, y_train)

# %% [markdown]
# ### model evaluation

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

r2 = r2_score(y_test, y_predictions)
mean_squared_error = mean_squared_error(y_test, y_predictions )
mean_absolute_error = mean_absolute_error(y_test, y_predictions)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_predictions, color='blue', alpha=0.5, label='Predictions')

# Add a red dashed line representing a perfect 1-to-1 prediction
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=2, label='Perfect Fit')

plt.xlabel('Actual Strength (MPa)')
plt.ylabel('Predicted Strength (MPa)')
plt.title('Actual vs. Predicted Concrete Strength')
plt.legend()
plt.show()
